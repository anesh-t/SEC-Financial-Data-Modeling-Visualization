# %% [markdown]
# # Part II

# %%
# !createdb -U student financial_db  # Create a new financial_db database
# Out:
# createdb: error: database creation failed: ERROR:  database "financial_db" already exists

# %% [markdown]
# **Drop the financial_db database if it exists**

# %%
# !psql -U student -l
# Out:
#                                List of databases
#      Name     |  Owner   | Encoding | Collate |  Ctype  |   Access privileges
# --------------+----------+----------+---------+---------+-----------------------
#  financial_db | student  | UTF8     | C.UTF-8 | C.UTF-8 |
#  postgres     | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
#  template0    | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#               |          |          |         |         | postgres=CTc/postgres
#  template1    | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#               |          |          |         |         | postgres=CTc/postgres
#  week6        | student  | UTF8     | C.UTF-8 | C.UTF-8 |
# (5 rows)

# %% [markdown]
# **List all the database**

# %%
# %load_ext sql

# %% [markdown]
# **Load the SQL extension to enable SQL code execution in Jupyter Notebook**

# %%
# %sql postgresql://student@localhost/financial_db

# %% [markdown]
# **Connect to the financial_db database using the student user**

# %%
# %%sql
# DROP TABLE IF EXISTS SUB CASCADE;
#
# CREATE TABLE SUB (
#     adsh VARCHAR(20) NOT NULL PRIMARY KEY,  -- Primary key, uniquely identifies each submission
#     cik NUMERIC(10) NOT NULL,  -- Company identifier
#     name VARCHAR(150) NOT NULL,  -- Company name
#     sic NUMERIC(4),
#     countryba VARCHAR(2),  -- Country of business address
#     stprba VARCHAR(2),
#     cityba VARCHAR(30),
#     zipba VARCHAR(10),
#     bas1 VARCHAR(40),
#     bas2 VARCHAR(40),
#     baph VARCHAR(20),
#     countryma VARCHAR(2),
#     stprma VARCHAR(2),
#     cityma VARCHAR(30),
#     zipma VARCHAR(10),
#     mas1 VARCHAR(40),
#     mas2 VARCHAR(40),
#     countryinc VARCHAR(2),
#     stprinc VARCHAR(2),
#     ein NUMERIC(10),
#     former VARCHAR(150),
#     changed VARCHAR(8),
#     afs VARCHAR(5),
#     wksi BOOLEAN NOT NULL,
#     fye VARCHAR(4),
#     form VARCHAR(20) NOT NULL,
#     period DATE,
#     fy NUMERIC(4),
#     fp VARCHAR(2),
#     filed DATE NOT NULL,
#     accepted DATE NOT NULL,
#     prevrpt BOOLEAN NOT NULL,
#     detail BOOLEAN NOT NULL,
#     instance VARCHAR(32) NOT NULL,
#     nciks NUMERIC(4) NOT NULL,
#     aciks VARCHAR(120),
#     pubfloatusd NUMERIC(15,2),
#     floatdate DATE,
#     floataxis VARCHAR(255),
#     floatmems NUMERIC(1)
# );
# Out:
#  * postgresql://student@localhost/financial_db
# Done.
# Done.
# []

# %% [markdown]
# **Drop the existing table if it exists, then create a new table 'SUB' with various columns for storing company submission details, including identifiers, addresses, and financial data**

# %%
# %%sql
# DROP TABLE IF EXISTS TAG CASCADE;
#
# CREATE TABLE TAG (
#     tag VARCHAR(256) NOT NULL,  -- Identifies the tag
#     version VARCHAR(20) NOT NULL,  -- Version of the tag
#     custom BOOLEAN NOT NULL,  -- Custom field for additional info
#     abstract BOOLEAN NOT NULL,  -- Describes the tag
#     datatype VARCHAR(20),  -- Data type of the tag
#     iord VARCHAR(1),
#     crdr VARCHAR(1),
#     tlabel VARCHAR(512),
#     doc VARCHAR(2048),
#     PRIMARY KEY (tag, version)  -- Set a composite primary key on (tag, version)
# );
# Out:
#  * postgresql://student@localhost/financial_db
# Done.
# Done.
# []

# %% [markdown]
# **Drop the existing 'TAG' table if it exists, then create a new table 'TAG' with columns for tag identifiers, versioning, and metadata, setting a composite primary key on (tag, version)**

# %%
# %%sql
# DROP TABLE IF EXISTS PRE CASCADE;
#
# CREATE TABLE PRE (
#     adsh VARCHAR(20) NOT NULL,  -- Foreign key, references the SUB table
#     report NUMERIC(6) NOT NULL,
#     line NUMERIC(6) NOT NULL,  -- Line number in the report
#     stmt VARCHAR(2),
#     inpth BOOLEAN NOT NULL,
#     tag VARCHAR(256) NOT NULL,  -- Foreign key, references the TAG table
#     version VARCHAR(20) NOT NULL,  -- Foreign key, references the TAG table
#     prole VARCHAR(50) NOT NULL,  -- Role of the person creating the report
#     plabel VARCHAR(512),  -- Label of the financial data in the report
#     negating BOOLEAN NOT NULL,
#     PRIMARY KEY (adsh, report, line), -- Set a composite primary key on (adsh, report, line)
#     FOREIGN KEY (adsh) REFERENCES SUB(adsh),  -- Foreign key constraint referencing SUB table
#     FOREIGN KEY (tag, version) REFERENCES TAG(tag, version)  -- Foreign key constraint referencing TAG table
# );
# Out:
#  * postgresql://student@localhost/financial_db
# Done.
# Done.
# []

# %% [markdown]
# **Drop the existing 'PRE' table if it exists, then create a new table 'PRE' with columns for report details, including identifiers, line information, and metadata, setting a composite primary key on (adsh, report, line) and defining foreign key constraints referencing 'SUB' and 'TAG' tables**

# %%
# %%sql
# DROP TABLE IF EXISTS DIM CASCADE;
#
# CREATE TABLE DIM (
#     dimh VARCHAR(35) NOT NULL PRIMARY KEY,  -- Primary key, uniquely identifies each dimension
#     segment VARCHAR(1024),  -- Segment of the financial data
#     segt BOOLEAN NOT NULL
# );
# Out:
#  * postgresql://student@localhost/financial_db
# Done.
# Done.
# []

# %% [markdown]
# **Drop the existing 'DIM' table if it exists, then create a new table 'DIM' with columns for dimension identifiers and segment details, setting 'dimh' as the primary key**

# %%
# %%sql
# DROP TABLE IF EXISTS NUM;
#
# CREATE TABLE NUM (
#     adsh VARCHAR(20) NOT NULL,  -- Foreign key, references the SUB table
#     tag VARCHAR(256) NOT NULL,  -- Foreign key, references the TAG table
#     version VARCHAR(20) NOT NULL,  -- Foreign key, references the TAG table
#     ddate DATE NOT NULL,  -- Date of the financial data
#     qtrs NUMERIC(8) NOT NULL,
#     uom VARCHAR(20) NOT NULL,
#     dimh VARCHAR(40) NOT NULL,  -- Foreign key, references the DIM table
#     iprx NUMERIC(2) NOT NULL,  -- IP-related identifier
#     value NUMERIC(16),  -- Numeric value of the financial data
#     footnote VARCHAR(512),
#     footlen NUMERIC(4) NOT NULL,
#     dimn NUMERIC(1) NOT NULL,
#     coreg VARCHAR(256),
#     durp NUMERIC(7,3) NOT NULL,
#     datp NUMERIC(7,3) NOT NULL,
#     dcml NUMERIC(5) NOT NULL,
#     PRIMARY KEY (adsh, tag, version, ddate, qtrs, uom, dimh, iprx),  -- Composite primary key
#     FOREIGN KEY (adsh) REFERENCES SUB(adsh),  -- Foreign key constraint referencing SUB table
#     FOREIGN KEY (tag, version) REFERENCES TAG(tag, version),  -- Foreign key constraint referencing TAG table
#     FOREIGN KEY (dimh) REFERENCES DIM(dimh)  -- Foreign key constraint referencing DIM table
# );
# Out:
#  * postgresql://student@localhost/financial_db
# Done.
# Done.
# []

# %% [markdown]
# **Drop the existing 'NUM' table if it exists, then create a new table 'NUM' for detailed financial data with identifiers, dates, numeric values, and metadata. Define a composite primary key and set foreign key constraints referencing the 'SUB', 'TAG', and 'DIM' tables**

# %%
#!wget -O 2024_01_SEC-data.zip https://www.sec.gov/files/dera/data/financial-statement-notes-data-sets/2024_01_notes.zip

# %%
#!unzip -o 2024_01_notes

# %% [markdown]
# **Download and extract the data from the SEC website**

# %% [markdown]
# Note that this function did not work with the SEC site so our files were downloaded and extracted manually.

# %%
#!csvformat -T dim.tsv > dim.csv
#!csvformat -T num.tsv > num.csv
#!csvformat -T tag.tsv > tag.csv
#!csvformat -T sub.tsv > sub.csv
#!csvformat -T pre.tsv > pre.csv

# %% [markdown]
# **Convert the filetype to CSV**

# %%
# %%sql
# COPY SUB FROM '/home/ubuntu/notebooks/homework 2/sub.csv'
# CSV
# HEADER;
# Out:
#  * postgresql://student@localhost/financial_db
# 5904 rows affected.
# []

# %%
# %%sql
# COPY TAG FROM '/home/ubuntu/notebooks/homework 2/tag.csv'
# CSV
# HEADER;
# Out:
#  * postgresql://student@localhost/financial_db
# 84276 rows affected.
# []

# %%
# %%sql
# COPY PRE FROM '/home/ubuntu/notebooks/homework 2/pre.csv'
# CSV
# HEADER;
# Out:
#  * postgresql://student@localhost/financial_db
# 511413 rows affected.
# []

# %%
# %%sql
# COPY DIM FROM '/home/ubuntu/notebooks/homework 2/dim.csv'
# CSV
# HEADER;
# Out:
#  * postgresql://student@localhost/financial_db
# 43201 rows affected.
# []

# %%
# %%sql
# COPY NUM FROM '/home/ubuntu/notebooks/homework 2/num.csv'
# CSV
# HEADER;
# Out:
#  * postgresql://student@localhost/financial_db
# 598843 rows affected.
# []

# %% [markdown]
# **Load data into the proper database tables**

# %%
# !csvstat --count sub.csv
# !csvstat --count tag.csv
#!csvstat --count pre.csv
# !csvstat --count dim.csv
#!csvstat --count num.csv
# Out:
# 5904
# 84276
# 43201

# %% [markdown]
# **Verify file row counts equal tables**

# %% [markdown]
# Note that the PRE and NUM files require additional processing power as they are so large.

# %% [markdown]
# # Part III
#
# **Formulate SQL queries from question prompts**

# %%
# %%sql
# SELECT DISTINCT SUB.adsh submission_id, SUB.name company_name, SUB.filed submission_date,
#         SUB.bas1 || ' ' || SUB.bas2 || ' ' || SUB.cityba || ' ' || SUB.zipba || ' ' || SUB.countryba mailing_address
# FROM SUB
# WHERE SUB.sic in (6321, 8000, 8082, 8090)
# Out:
#  * postgresql://student@localhost/financial_db
# 37 rows affected.
# [('0000004977-24-000006', 'AFLAC INC', datetime.date(2024, 1, 31), None),
#  ('0000005513-24-000003', 'UNUM GROUP', datetime.date(2024, 1, 4), None),
#  ('0000005513-24-000008', 'UNUM GROUP', datetime.date(2024, 1, 30), None),
#  ('0000885978-24-000002', 'U S PHYSICAL THERAPY INC /NV', datetime.date(2024, 1, 9), '1300 WEST SAM HOUSTON PARKWAY SUITE 300 HOUSTON 77043 US'),
#  ('0000950170-24-004820', 'AVEANNA HEALTHCARE HOLDINGS, INC.', datetime.date(2024, 1, 17), '400 INTERSTATE NORTH PARKWAY STE 1700 ATLANTA 30339 US'),
#  ('0000950170-24-005016', 'MARPAI, INC.', datetime.date(2024, 1, 17), '615 CHANNELSIDE DRIVE SUITE 207 TAMPA 33602 US'),
#  ('0000950170-24-005385', 'MARPAI, INC.', datetime.date(2024, 1, 18), '615 CHANNELSIDE DRIVE SUITE 207 TAMPA 33602 US'),
#  ('0001104659-24-001643', 'GREENBROOK TMS INC.', datetime.date(2024, 1, 5), None),
#  ('0001104659-24-003303', 'PRINCIPAL FINANCIAL GROUP INC', datetime.date(2024, 1, 11), None),
#  ('0001104659-24-005618', 'GREENBROOK TMS INC.', datetime.date(2024, 1, 22), None),
#  ('0001104659-24-005943', 'DIGITAL HEALTH ACQUISITION CORP.', datetime.date(2024, 1, 23), '980 N FEDERAL HWY #304 BOCA RATON 33432 US'),
#  ('0001104659-24-006683', 'PRINCIPAL FINANCIAL GROUP INC', datetime.date(2024, 1, 25), None),
#  ('0001104659-24-007734', 'GREENBROOK TMS INC.', datetime.date(2024, 1, 29), None),
#  ('0001185185-24-000044', 'PACIFIC HEALTH CARE ORGANIZATION INC', datetime.date(2024, 1, 5), '1201 DOVE STREET SUITE 300 NEWPORT BEACH 92260 US'),
#  ('0001185185-24-000060', 'MITESCO, INC.', datetime.date(2024, 1, 10), None),
#  ('0001185185-24-000095', 'MITESCO, INC.', datetime.date(2024, 1, 18), None),
#  ('0001185185-24-000124', 'MITESCO, INC.', datetime.date(2024, 1, 30), None),
#  ('0001193125-24-004495', 'BETTER THERAPEUTICS, INC.', datetime.date(2024, 1, 8), None),
#  ('0001213900-24-005356', 'ACHARI VENTURES HOLDINGS CORP. I', datetime.date(2024, 1, 22), None),
#  ('0001493152-23-046641', 'MANGOCEUTICALS, INC.', datetime.date(2024, 1, 2), None),
#  ('0001493152-24-000083', 'AGAPE ATP CORP', datetime.date(2024, 1, 2), '1705-1708 LEVEL 17, TOWER 2, FABER TOWER JALAN DESA BAHAGIA, TAMAN DESA KUALA LUMPUR 58100 MY'),
#  ('0001493152-24-003174', 'AGAPE ATP CORP', datetime.date(2024, 1, 22), '1705-1708 LEVEL 17, TOWER 2, FABER TOWER JALAN DESA BAHAGIA, TAMAN DESA KUALA LUMPUR 58100 MY'),
#  ('0001493152-24-003338', 'MANGOCEUTICALS, INC.', datetime.date(2024, 1, 23), None),
#  ('0001493152-24-003785', 'MANGOCEUTICALS, INC.', datetime.date(2024, 1, 25), None),
#  ('0001628280-24-000516', 'AGILON HEALTH, INC.', datetime.date(2024, 1, 5), '6210 E HWY 290 SUITE 450 AUSTIN 78723 US'),
#  ('0001628280-24-000518', 'AGILON HEALTH, INC.', datetime.date(2024, 1, 5), '6210 E HWY 290 SUITE 450 AUSTIN 78723 US'),
#  ('0001628280-24-000993', 'P3 HEALTH PARTNERS INC.', datetime.date(2024, 1, 10), '2045 W GRAND AVE STE B PMB # 82152 CHICAGO 60612-1577 US'),
#  ('0001683168-24-000004', 'MEDICALE CORP.', datetime.date(2024, 1, 2), '9314 FOREST HILL BLVD #929 WELLINGTON 33411 US'),
#  ('0001683168-24-000525', 'WELSIS CORP.', datetime.date(2024, 1, 29), None),
#  ('0001759655-24-000004', 'PRIVIA HEALTH GROUP, INC.', datetime.date(2024, 1, 8), None),
#  ('0001759655-24-000011', 'PRIVIA HEALTH GROUP, INC.', datetime.date(2024, 1, 29), None),
#  ('0001770141-24-000003', 'UPHEALTH, INC.', datetime.date(2024, 1, 18), '14000 S. MILITARY TRAIL SUITE 203 DELRAY BEACH 33484 US'),
#  ('0001818331-24-000003', 'GENEDX HOLDINGS CORP.', datetime.date(2024, 1, 8), '333 LUDLOW STREET NORTH TOWER, 8TH FLOOR STAMFORD 06902 US'),
#  ('0001822359-24-000005', 'DOCGO INC.', datetime.date(2024, 1, 10), '35TH STREET WEST 35TH FLOOR 6 NEW YORK 10001 US'),
#  ('0001822359-24-000007', 'DOCGO INC.', datetime.date(2024, 1, 16), '35TH STREET WEST 35TH FLOOR 6 NEW YORK 10001 US'),
#  ('0001822359-24-000009', 'DOCGO INC.', datetime.date(2024, 1, 31), '35TH STREET WEST 35TH FLOOR 6 NEW YORK 10001 US'),
#  ('0001822479-24-000003', 'SOTERA HEALTH CO', datetime.date(2024, 1, 9), None)]

# %% [markdown]
# **Question 1: Company submission and mailing info for Healthcare SICs**

# %% [markdown]
# Note that these SICs were taken directly from the SEC website (https://www.sec.gov/search-filings/standard-industrial-classification-sic-code-list)

# %%
# %%sql
# SELECT case
#         WHEN filed BETWEEN '2024-01-01' AND '2024-01-31' THEN 'JAN 2024'
#         WHEN filed BETWEEN '2024-02-01' AND '2024-02-28' THEN 'FEB 2024'
#         WHEN filed BETWEEN '2024-02-01' AND '2024-02-28' THEN 'FEB 2024'
#         WHEN filed BETWEEN '2024-02-01' AND '2024-02-28' THEN 'FEB 2024'
#         ELSE 'INVALID'
#         END AS month, count(DISTINCT adsh) total_submissions, count(DISTINCT adsh)/count(DISTINCT name) average_per_company
# FROM SUB
# GROUP BY month;
# Out:
#  * postgresql://student@localhost/financial_db
# 1 rows affected.
# [('JAN 2024', 5904, 1)]

# %% [markdown]
# **Question 2: Compute total submissions per month and average per company**

# %% [markdown]
# Note that the average calculation is an assumption as the question prompt was unclear.

# %%
# %%sql
# SELECT NUM.tag tag_id, TAG.tlabel tag_name, count(DISTINCT SUB.name) num_companies
# FROM TAG NATURAL JOIN NUM NATURAL JOIN SUB
# WHERE SUB.sic in (6021, 6029, 6035, 6036, 6099, 6111, 6141, 6153, 6159, 6162,
#                   6163, 6172, 6189, 6199, 6200, 6211, 6221, 6282, 6311, 6321, 6324, 6331, 6351, 6361, 6399, 6411)
# GROUP BY NUM.tag, TAG.tlabel;
# Out:
#  * postgresql://student@localhost/financial_db
# 2539 rows affected.
# [('AccountingProfit', 'Accounting profit', 1),
#  ('AccountsAndNotesReceivableNet', 'Accounts and Financing Receivable, after Allowance for Credit Loss', 1),
#  ('AccountsAndOtherReceivablesNetCurrent', 'Accounts and Other Receivables, Net, Current', 1),
#  ('AccountsNotesAndLoansReceivableNetCurrent', 'Accounts and Financing Receivable, after Allowance for Credit Loss, Current', 1),
#  ('AccountsPayableAndAccruedLiabilitiesCurrent', 'Accounts Payable and Accrued Liabilities, Current', 2),
#  ('AccountsPayableAndAccruedLiabilitiesCurrentAndNoncurrent', 'Accounts Payable and Accrued Liabilities', 3),
#  ('AccountsPayableAndOtherAccruedLiabilities', 'Accounts Payable and Other Accrued Liabilities', 2),
#  ('AccountsPayableCurrent', 'Accounts payable', 6),
#  ('AccountsReceivableGross', 'Accounts Receivable, before Allowance for Credit Loss', 1),
#  ('AccountsReceivableNet', 'Accounts Receivable, after Allowance for Credit Loss', 1),
#  ('AccountsReceivableNetCurrent', 'Accounts Receivable, after Allowance for Credit Loss, Current', 1),
#  ('AccretionAmortizationOfDiscountsAndPremiumsInvestments', 'Accretion (Amortization) of Discounts and Premiums, Investments', 1),
#  ('AccretionAndFinanceLeaseRightOfUseAssetAmortization', 'Accretion And Finance Lease, Right-of-Use Asset, Amortization', 1),
#  ('AccretionOfCommonStockSubjectToRedemption', 'Accretion of Common Stock subject to redemption', 1),
#  ('AccruedBonusesCurrent', 'Accrued Bonuses, Current', 2),
#  ('AccruedContractors', 'Accrued Contractors', 1),
#  ('AccruedEmployeeBenefitsCurrent', 'Accrued Employee Benefits, Current', 1),
#  ('AccruedIncomeTaxes', 'Accrued Income Taxes', 3),
#  ('AccruedInterestExpenseOnLeaseLiabilities', 'Accrued interest expense on lease liabilities', 1),
#  ('AccruedInvestmentIncomeReceivable', 'Accrued Investment Income Receivable', 3),
#  ('AccruedLiabilitiesAndOtherLiabilities', 'Accrued Liabilities and Other Liabilities', 1),
#  ('AccruedLiabilitiesCurrent', 'Accrued Liabilities, Current', 2),
#  ('AccruedLiabilitiesCurrentAndNoncurrent', 'Accrued Liabilities', 1),
#  ('AccruedProfessionalFeesCurrent', 'Accrued professional fees', 1),
#  ('AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment', 'Accumulated Depreciation, Depletion and Amortization, Property, Plant, and Equipment', 6),
#  ('AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipmentPeriodIncreaseDecrease', 'Accumulated Depreciation, Depletion and Amortization, Property, Plant and Equipment, Period Increase (Decrease)', 1),
#  ('AccumulatedEquityAndAnIncrease', 'Accumulated Equity And An Increase', 1),
#  ('AccumulatedOtherComprehensiveIncome', 'Accumulated other comprehensive income', 1),
#  ('AccumulatedOtherComprehensiveIncomeLossInvestmentSecuritiesBeforeTax', 'Accumulated Other Comprehensive Income (Loss), Investment Securities, Before Tax', 1),
#  ('AccumulatedOtherComprehensiveIncomeLossInvestmentSecuritiesNetOfTax', 'Accumulated Other Comprehensive Income (Loss), Investment Securities, Net of Tax', 1),
#  ('AccumulatedOtherComprehensiveIncomeLossInvestmentSecuritiesTaxExpenseBenefit', 'Accumulated Other Comprehensive Income (Loss), Investment Securities, Tax Expense (Benefit)', 1),
#  ('AccumulatedOtherComprehensiveIncomeLossNetOfTax', 'Accumulated other comprehensive income', 9),
#  ('AccumulatedOtherComprehensiveIncomeLossOtherThanTemporaryImpairmentAvailableForSaleDebtSecuritiesNetUnrealizedGains', 'Accumulated Other Comprehensive Income (Loss), Other than Temporary Impairment, Available-for-sale, Debt Securities, Net Unrealized Gains', 1),
#  ('AccumulatedOtherComprehensiveIncomeLossOtherthanTemporaryImpairmentNotCreditLossBeforeTaxAvailableforSaleDebtSecurities', 'Accumulated Other Comprehensive Income (Loss), Other than Temporary Impairment, Not Credit Loss, Before Tax, Available-for-Sale, Debt Securities', 1),
#  ('AcquisitionOfFinancialAssetsAtFVOCI', 'Acquisition of financial assets at FVOCI', 1),
#  ('AcquisitionOfFinancialAssetsAtFVTPL', 'Acquisition of financial assets at FVTPL', 1),
#  ('AcquisitionRelatedCostsRelatedToLegalFeesAndDueDiligence', 'Acquisition-related costs related to legal fees and due diligence', 1),
#  ('AcquisitiondateFairValueOfTotalConsiderationTransferred', 'Consideration transferred, acquisition-date fair value', 1),
#  ('AcquisitionsThroughBusinessCombinationsIntangibleAssetsOtherThanGoodwill', 'Acquisitions through business combinations, intangible assets other than goodwill', 1),
#  ('AcquisitionsThroughBusinessCombinationsPropertyPlantAndEquipment', 'Acquisitions through business combinations, property, plant and equipment', 1),
#  ('AdditionalCollateralAggregateFairValue', 'Additional Collateral, Aggregate Fair Value', 1),
#  ('AdditionalCommonStockSubjectToPossibleRedemption', 'Additional amount deposited into trust', 1),
#  ('AdditionalFuturePaymentsToAcquireBusiness', 'Additional future payments to Acquire Business', 1),
#  ('AdditionalPaidInCapital', 'Additional paid in capital', 8),
#  ('AdditionalPaidInCapitalCommonStock', 'Additional Paid in Capital, Common Stock', 5),
#  ('AdditionalProvisionsOtherProvisions', 'Additional provisions, other provisions', 1),
#  ('AdditionsEarnedDigitalCurrencies', 'Additions earned', 1),
#  ('AdditionsForOperatingLeaseLiability', 'AdditionsForOperatingLeaseLiability', 1),
#  ('AdditionsOfConvertibleNotesPayable', 'Additions', 1),
#  ('AdditionsOnRightOfUseAssetGross', 'AdditionsOnRightOfUseAssetGross', 1),
#  ('AdditionsOtherThanThroughBusinessCombinationsIntangibleAssetsOtherThanGoodwill', 'Additions other than through business combinations, intangible assets other than goodwill', 1),
#  ('AdditionsOtherThanThroughBusinessCombinationsPropertyPlantAndEquipment', 'Additions other than through business combinations, property, plant and equipment', 1),
#  ('AdditionsToContractHoldersFunds', 'Additions to Contract Holders Funds', 1),
#  ('AdjToCompAmt', 'Adjustment to Compensation Amount', 4),
#  ('AdjustmentForAmortization', 'Amortization', 1),
#  ('AdjustmentsForCurrentTaxExpense', 'Adjustments For Current Tax Expense', 1),
#  ('AdjustmentsForDecreaseIncreaseInDerivativeFinancialAssets', 'Adjustments for decrease (increase) in derivative financial assets', 1),
#  ('AdjustmentsForDecreaseIncreaseInLoansAndAdvancesToBanks', 'Adjustments for decrease (increase) in loans and advances to banks', 1),
#  ('AdjustmentsForDecreaseIncreaseInLoansAndAdvancesToCustomers', 'Adjustments for decrease (increase) in loans and advances to customers', 1),
#  ('AdjustmentsForDecreaseIncreaseInMandatoryReserveDepositsAtCentraBanks', 'Adjustments For Decrease Increase In Mandatory Reserve Deposits At Centra Banks', 1),
#  ('AdjustmentsForDecreaseIncreaseInNoncurrentAssetsOrDisposalGroupsClassifiedAsHeldForSaleOrAsHeldForDistributionToOwners', 'Adjustments For Decrease Increase In Noncurrent Assets Or Disposal Groups Classified As Held For Sale Or As Held For Distribution To Owners', 1),
#  ('AdjustmentsForDecreaseIncreaseInOtherAssets', 'Adjustments for decrease (increase) in other assets', 1),
#  ('AdjustmentsForDecreaseIncreaseInSecurities', 'Adjustments For Decrease Increase In Securities', 1),
#  ('AdjustmentsForDeferredTaxExpense', 'Adjustments for deferred tax expense', 1),
#  ('AdjustmentsForDepreciationAndAmortisationExpense', 'Adjustments for depreciation and amortisation expense', 1),
#  ('AdjustmentsForImpairmentLossReversalOfImpairmentLossRecognisedInProfitOrLoss', 'Adjustments for impairment loss (reversal of impairment loss) recognised in profit or loss', 1),
#  ('AdjustmentsForIncreaseDecreaseInBorrowingAndOnlending', 'Adjustments For Increase Decrease In Borrowing And Onlending', 1),
#  ('AdjustmentsForIncreaseDecreaseInDepositsFromBanksAccruedPayableAndRepurchaseAgreementsAndCashCollateralOnSecuritiesLent', 'Adjustments For Increase Decrease In Deposits From Banks Accrued Payable And Repurchase Agreements And Cash Collateral On Securities Lent', 1),
#  ('AdjustmentsForIncreaseDecreaseInDepositsFromCustomers', 'Adjustments for increase (decrease) in deposits from customers', 1),
#  ('AdjustmentsForIncreaseDecreaseInDerivativeFinancialLiabilities', 'Adjustments for increase (decrease) in derivative financial liabilities', 1),
#  ('AdjustmentsForIncreaseDecreaseInEmployeeBenefitLiabilities', 'Adjustments for increase (decrease) in employee benefit liabilities', 1),
#  ('AdjustmentsForIncreaseDecreaseInOtherLiabilities', 'Adjustments for increase (decrease) in other liabilities', 1),
#  ('AdjustmentsForIncreaseDecreaseInOtherTaxLiabilities', 'Adjustments For Increase Decrease In Other Tax Liabilities', 1),
#  ('AdjustmentsForIncreaseDecreaseInProvision', 'Adjustments For Increase Decrease In Provision', 1),
#  ('AdjustmentsForIncreaseDecreaseInSecuritiesIssued', 'Adjustments For Increase Decrease In Securities Issued', 1),
#  ('AdjustmentsForOtherCapitalGainsLosses', 'Adjustments For Other capital gains (losses)', 1),
#  ('AdjustmentsForProvisionForPerformanceIncome', 'Adjustments for Provision for performance income', 1),
#  ('AdjustmentsForProvisions', 'Adjustments for provisions', 1),
#  ('AdjustmentsForProvisionsForLossOfAssets', 'Adjustments For Provisions For Loss of Assets', 1),
#  ('AdjustmentsForUndistributedProfitsOfAssociates', 'Adjustments for undistributed profits of associates', 1),
#  ('AdjustmentsForUnrealisedForeignExchangeLossesGains', 'Adjustments for unrealised foreign exchange losses (gains)', 1),
#  ('AdjustmentsRelatedToTaxWithholdingForShareBasedCompensation', 'Share-Based Payment Arrangement, Decrease for Tax Withholding Obligation', 1),
#  ('AdjustmentsToAdditionalPaidInCapitalDividendEquivalents', 'Adjustments To Additional Paid In Capital, Dividend Equivalents', 1),
#  ('AdjustmentsToAdditionalPaidInCapitalIncreaseInCarryingAmountOfRedeemablePreferredStock', 'Adjustments to Additional Paid in Capital, Increase in Carrying Amount of Redeemable Preferred Stock', 1),
#  ('AdjustmentsToAdditionalPaidInCapitalMarkToMarket', 'Adjustments to Additional Paid in Capital, Fair Value', 1),
#  ('AdjustmentsToAdditionalPaidInCapitalOther', 'Adjustments to Additional Paid in Capital, Other', 1),
#  ('AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue', 'Share-based expense', 5),
#  ('AdjustmentsToAdditionalPaidInCapitalStockIssuedIssuanceCosts', 'Adjustments to Additional Paid in Capital, Stock Issued, Issuance Costs', 2),
#  ('AdministrativeExpense', 'Administrative expenses', 1),
#  ('AdvanceFeePercentage', 'Advance fee, percentage', 1),
#  ('AdvancePaymentToThirdParties', 'Advance Payment To Third-Parties', 1),
#  ('AdvancePaymentsByBorrowersForTaxesAndInsurance', 'Advance Payments by Borrowers for Taxes and Insurance', 1),
#  ('AdvancesFromFederalHomeLoanBanks', 'Advance from Federal Home Loan Bank', 1),
#  ('AdvancesFromSubsidiaries', 'Advances From Subsidiaries', 1),
#  ('AdvancesToAffiliate', 'Advances to Affiliate', 1),
#  ('AdvertisingExpense', 'Advertising expense', 1),
#  ('AggregateLoanCommitment', 'Aggregate Loan Commitment', 1),
#  ('AggregateMaturities', 'Aggregate Maturities', 1),
#  ('AggregateStockPrice', 'Aggregate Stock Price', 1),
#  ('AggregateValueOfExchangeableShares', 'Aggregate Value Of Exchangeable Shares', 1),
#  ('AggregationOfOrdinaryShares', 'Aggregation Of Ordinary Shares', 1),
#  ('AgreedCashConsideration', 'Agreed Cash Consideration', 1),
#  ('AgreementsToBeTransferred', 'Agreements to be Transferred', 1),
#  ('AllocatedShareBasedCompensationExpense', 'Share-based compensation expense', 3),
#  ('AllocatedShareBasedCompensationExpenseNetOfTax', 'Share-Based Payment Arrangement, Expense, after Tax', 1),
#  ('AllowanceForDoubtfulAccountsReceivable', 'Accounts Receivable, Allowance for Credit Loss', 1),
#  ('AllowanceForDoubtfulAccountsReceivableCurrent', 'Accounts Receivable, Allowance for Credit Loss, Current', 1),
#  ('AllowanceForDoubtfulAccountsReceivableRecoveries', 'Accounts Receivable, Allowance for Credit Loss, Recovery', 1),
#  ('AllowanceForDoubtfulAccountsReceivableWriteOffs', 'Accounts Receivable, Allowance for Credit Loss, Writeoff', 2),
#  ('AlternativeExcessNetCapital', 'Broker-Dealer, Excess Net Capital, Alternative Standard', 2),
#  ('AlternativeInvestment', 'Alternative Investment', 2),
#  ('AmortisationIntangibleAssetsOtherThanGoodwill', 'Amortisation, intangible assets other than goodwill', 1),
#  ('AmortisationRateIntangibleAssetsAndGoodwill', 'Amortisation Rate, Intangible Assets and Goodwill', 1),
#  ('AmortizationOfAcquisitionCosts', 'Amortization of Acquisition Costs', 1),
#  ('AmortizationOfCryptoEquipment', 'Amortization of Crypto equipment', 1),
#  ('AmortizationOfDebtDiscountPremium', 'Amortization of Debt Discount (Premium)', 1),
#  ('AmortizationOfDeferredLoanOriginationFeesNet', 'Amortization of Deferred Loan Origination Fees, Net', 1),
#  ('AmortizationOfDeferredSalesCommissions', 'Amortization of Deferred Sales Commissions', 1),
#  ('AmortizationOfDiscountOnPromissoryNote', 'Amortization of discount on promissory note', 1),
#  ('AmortizationOfFinancingCosts', 'Amortization of Debt Issuance Costs', 1),
#  ('AmortizationOfFinancingCostsAndDiscounts', 'Amortization of Debt Issuance Costs and Discounts', 2),
#  ('AmortizationOfGuaranteeFee', 'Amortization Of Guarantee Fee', 1),
#  ('AmortizationOfIntangibleAssets', 'Amortization', 3),
#  ('AmortizationOfLicense', 'Amortization of license', 1),
#  ('AmountOfRestrictedNetAssetsForConsolidatedAndUnconsolidatedSubsidiaries', 'Amount of Restricted Net Assets for Consolidated and Unconsolidated Subsidiaries', 1),
#  ('AmountOfRestrictedNetAssetsForConsolidatedAndUnconsolidatedSubsidiariesRegulatoryCapitalRequirementsOrRegulatoryApprovalRequired', 'Amount of Restricted Net Assets for Consolidated and Unconsolidated Subsidiaries, Regulatory Capital Requirements Or Regulatory Approval Required', 1),
#  ('AmountOwedToRelatedParty', 'Amount owed to related Party', 1),
#  ('AmountPaidPurchasePrice', 'Paid total purchase price', 1),
#  ('AmountRecognizedInNetPeriodicBenefitCostAndOtherComprehensiveIncomeLossBeforeTax', 'Defined Benefit Plan, Amount Recognized in Net Periodic Benefit Cost (Credit) and Other Comprehensive (Income) Loss, before Tax', 1),
#  ('AmountsReceivableRelatedPartyTransactions', 'Amounts receivable, related party transactions', 1),
#  ('AnnualTargetedLongTermCompensation', 'Annual Targeted Long-Term Compensation', 1),
#  ('AnnualTargetedLongTermCompensationAdditionalIncentiveCompensationPercentage', 'Annual Targeted Long-Term Compensation, Additional Incentive Compensation, Percentage', 1),
#  ('AnnualTargetedLongTermCompensationPerformanceMeasurementBenchmarkGrowthRateInTotalShareholderReturnPercentage', 'Annual Targeted Long-Term Compensation, Performance Measurement Benchmark, Growth Rate In Total Shareholder Return, Percentage', 1),
#  ('AnnualTargetedLongTermCompensationPerformanceMeasurementBenchmarkGrowthRateInTotalShareholderReturnandTangibleDeployableEquityPercentageMaximum', 'Annual Targeted Long-Term Compensation, Performance Measurement Benchmark, Growth Rate In Total Shareholder Return and Tangible Deployable Equity, Percentage, Maximum', 1),
#  ('AnnualTargetedLongTermCompensationPerformanceMeasurementBenchmarkGrowthRateInTotalShareholderReturnandTangibleDeployableEquityPercentageMinimum', 'Annual Targeted Long-Term Compensation, Performance Measurement Benchmark, Growth Rate In Total Shareholder Return and Tangible Deployable Equity, Percentage, Minimum', 1),
#  ('AnnualTargetedLongTermCompensationPerformanceMeasurementBenchmarkGrowthRateReturnOnTangibleDeployableEquityPercentage', 'Annual Targeted Long-Term Compensation, Performance Measurement Benchmark, Growth Rate Return On Tangible Deployable Equity, Percentage', 1),
#  ('AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount', 'Antidilutive shares', 2),
#  ('AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerSharePercentOfWeightedAverageCommonSharesOutstanding', 'Antidilutive Securities Excluded From Computation Of Earnings Per Share, Percent Of Weighted Average Common Shares Outstanding', 1),
#  ('AociLossCashFlowHedgeCumulativeGainLossAfterTax', 'AOCI, Cash Flow Hedge, Cumulative Gain (Loss), after Tax', 1),
#  ('ApplicableTaxRate', 'Applicable tax rate', 1),
#  ('AssetAcquisitionConsiderationTransferred', 'Asset Acquisition, Consideration Transferred', 1),
#  ('AssetAcquisitionGainLossOnTransaction', 'Asset Acquisition, Gain (Loss) on Transaction', 1),
#  ('AssetImpairmentCharges', 'Asset Impairment Charges', 1),
#  ('Assets', 'Assets', 17),
#  ('AssetsCurrent', 'Assets, Current', 7),
#  ('AssetsDisposedOfByMethodOtherThanSaleInPeriodOfDispositionGainLossOnDisposition1', 'Assets Disposed of by Method Other than Sale, in Period of Disposition, Gain (Loss) on Disposition', 1),
#  ('AssetsFairValueDisclosure', 'Assets, Fair Value Disclosure', 4),
#  ('AssetsHeldForSaleNotPartOfDisposalGroupCurrent', 'Asset, Held-for-Sale, Not Part of Disposal Group, Current', 1),
#  ('AssetsHeldForSaleNotPartOfDisposalGroupNonCurrent', 'Assets Held For Sale Not Part Of Disposal Group Non Current', 1),
#  ('AssetsNeededForImmediateSettlementAggregateFairValue', 'Assets Needed for Immediate Settlement, Aggregate Fair Value', 1),
#  ('AssetsNet', 'Net Assets', 2),
#  ('AssetsNoncurrent', 'Assets, Noncurrent', 1),
#  ('AssetsOfDisposalGroupIncludingDiscontinuedOperation', 'Disposal Group, Including Discontinued Operation, Assets', 2),
#  ('AssetsOtherThanReceivables', 'Assets Other than Receivables', 1),
#  ('AssetsPledgedAsCollateral', 'Assets Pledged as Collateral', 1),
#  ('AssetsReceivedForImmediateSettlementAggregateFairValue', 'Assets Received for Immediate Settlement Aggregate Fair Value', 1),
#  ('AssetsThatEntityContinuesToRecogniseToExtentOfContinuingInvolvement', 'Assets that entity continues to recognise to extent of continuing involvement', 1),
#  ('AssetsTransferredDueToSecuritization', 'Assets Transferred Due To Securitization', 1),
#  ('AssetsWrittenOff', 'Assets Written Off', 1),
#  ('AuthorizedShareCapitalValue', 'Authorized Share Capital, Value', 1),
#  ('AuthorizedShares', 'authorized shares', 1),
#  ('AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedGainBeforeTax', 'Debt Securities, Available-for-Sale, Accumulated Gross Unrealized Gain, before Tax', 2),
#  ('AvailableForSaleDebtSecuritiesAccumulatedGrossUnrealizedLossBeforeTax', 'Debt Securities, Available-for-Sale, Accumulated Gross Unrealized Loss, before Tax', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterFiveThroughTenYearsAmortizedCost', 'Debt Securities, Available-for-Sale, Amortized Cost, Maturity, Allocated and Single Maturity Date, after Year 5 Through 10', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterFiveThroughTenYearsFairValue', 'Debt Securities, Available-for-Sale, Fair Value, Maturity, Allocated and Single Maturity Date, after Year 5 Through 10', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterOneThroughFiveYearsAmortizedCost', 'Debt Securities, Available-for-Sale, Amortized Cost, Maturity, Allocated and Single Maturity Date, after Year One Through Five', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterOneThroughFiveYearsFairValue', 'Debt Securities, Available-for-Sale, Fair Value, Maturity, Allocated and Single Maturity Date, after Year One Through Five', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterTenYearsAmortizedCost', 'Debt Securities, Available-for-Sale, Amortized Cost, Maturity, Allocated and Single Maturity Date, after Year 10', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesAfterTenYearsFairValue', 'Debt Securities, Available-for-Sale, Fair Value, Maturity, Allocated and Single Maturity Date, after Year 10', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesWithinOneYearAmortizedCost', 'Debt Securities, Available-for-Sale, Amortized Cost, Maturity, Allocated and Single Maturity Date, Year One', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesWithinOneYearFairValue', 'Debt Securities, Available-for-Sale, Fair Value, Maturity, Allocated and Single Maturity Date, Year One', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesWithoutSingleMaturityDateAmortizedCost', 'Debt Securities, Available-for-Sale, Maturity, without Single Maturity Date, Amortized Cost', 2),
#  ('AvailableForSaleSecuritiesDebtMaturitiesWithoutSingleMaturityDateFairValue', 'Debt Securities, Available-for-Sale, Maturity, without Single Maturity Date, Fair Value', 1),
#  ('AvailableForSaleSecuritiesDebtSecurities', 'Debt Securities, Available-for-Sale', 1),
#  ('AvailableForSaleSecuritiesYieldAfterFiveThroughTenYears', 'Available-For-Sale Securities, Yield, After Five Through Ten Years', 1),
#  ('AvailableForSaleSecuritiesYieldAfterOneThroughFiveYears', 'Available-For-Sale Securities, Yield, After One Through Five Years', 1),
#  ('AvailableForSaleSecuritiesYieldAfterTenYears', 'Available-For-Sale Securities, Yield, After Ten Years', 1),
#  ('AvailableForSaleSecuritiesYieldOneYear', 'Available-For-Sale Securities, Yield, One Year', 1),
#  ('AvailableForSaleSecuritiesYieldWithoutSingleMaturity', 'Available-For-Sale Securities, Yield, Without Single Maturity', 1),
#  ('BadDebtExpenses', 'Bad Debt Expenses', 1),
#  ('BalanceInTrustAccount', 'Trust account balance before deposit of extension payment', 1),
#  ('BalancesOnCurrentAccountsFromCustomers', 'Balances on current accounts from customers', 1),
#  ('BalancesOnDemandDepositsFromCustomers', 'Balances on demand deposits from customers', 1),
#  ('BalancesOnTermDepositsFromCustomers', 'Balances on term deposits from customers', 1),
#  ('BankAndSimilarCharges', 'Bank and similar charges', 1),
#  ('BankOwnedLifeInsurance', 'Bank Owned Life Insurance', 1),
#  ('BankOwnedLifeInsuranceIncome', 'Bank Owned Life Insurance Income', 1),
#  ('BankingandServicesFees', 'Banking and Services Fees', 1),
#  ('BasicAndDilutedLossPerShare', 'Basic and diluted loss per share', 1),
#  ('BasicAndDilutedPerShare', 'Basic and diluted', 1),
#  ('BasicEarningsLossPerShare', 'Basic earnings (loss) per share', 1),
#  ('Borrowings', 'Borrowings', 1),
#  ('BorrowingsInterestRate', 'Borrowings, interest rate', 1),
#  ('BrokerDealerFeeIncome', 'Broker Dealer Fee Income', 1),
#  ('BrokerageCommissionsRevenue', 'Brokerage Commissions Revenue', 1),
#  ('BrokerageFeeIncome', 'Brokerage fee income', 1),
#  ('BusinessAcquisitionCostOfAcquiredEntityTransactionCosts', 'Business Acquisition, Transaction Costs', 1),
#  ('BusinessAcquisitionEquityInterestsIssuedOrIssuableNumberOfSharesIssued', 'Business Acquisition, Equity Interest Issued or Issuable, Number of Shares', 1),
#  ('BusinessAcquisitionPercentageOfVotingInterestsAcquired', 'Business Acquisition, Percentage of Voting Interests Acquired', 1),
#  ('BusinessAcquisitionsProFormaNetIncomeLoss', 'Business Acquisition, Pro Forma Net Income (Loss)', 1),
#  ('BusinessAcquisitionsProFormaRevenue', 'Business Acquisition, Pro Forma Revenue', 1),
#  ('BusinessAcquisitionsPurchasePriceAllocationSubsequentYearsRemainingAdjustments', 'Business Acquisitions, Purchase Price Allocation, Subsequent Years, Remaining Adjustments', 1),
#  ('BusinessCombinationConditionMinimumTangibleAssets', 'Minimum net tangible asset upon consummation of business combination', 1),
#  ('BusinessCombinationConsiderationTransferred1', 'Business Combination, Consideration Transferred', 2),
#  ('BusinessCombinationConsiderationTransferredCash', 'Business Combination Consideration Transferred Cash', 1),
#  ('BusinessCombinationConsiderationTransferredEquityInterestsIssuedAndIssuable', 'Business Combination, Consideration Transferred, Equity Interests Issued and Issuable', 1),
#  ('BusinessCombinationConsiderationTransferredIncludingEquityInterestInAcquireeHeldPriorToCombination1', 'Business Combination, Consideration Transferred, Including Equity Interest in Acquiree Held Prior to Combination', 1),
#  ('BusinessCombinationConsiderationTransferredLiabilitiesIncurred', 'Business Combination, Consideration Transferred, Liabilities Incurred', 1),
#  ('BusinessCombinationContingentConsiderationArrangementsChangeInAmountOfContingentConsiderationAsset1', 'Business Combination, Contingent Consideration Arrangements, Change in Amount of Contingent Consideration, Asset', 1),
#  ('BusinessCombinationContingentConsiderationArrangementsChangeInAmountOfContingentConsiderationLiability1', 'Business Combination, Contingent Consideration Arrangements, Change in Amount of Contingent Consideration, Liability', 1),
#  ('BusinessCombinationContingentConsiderationLiability', 'Business Combination, Contingent Consideration, Liability', 2),
#  ('BusinessCombinationContingentConsiderationLiabilityCurrent', 'Business Combination, Contingent Consideration, Liability, Current', 1),
#  ('BusinessCombinationProFormaInformationEarningsOrLossOfAcquireeSinceAcquisitionDateActual', 'Business Combination, Pro Forma Information, Earnings or Loss of Acquiree since Acquisition Date, Actual', 1),
#  ('BusinessCombinationProFormaInformationRevenueOfAcquireeSinceAcquisitionDateActual', 'Business Combination, Pro Forma Information, Revenue of Acquiree since Acquisition Date, Actual', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumeAccruedExpensesAndOtherLiabilities', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assume Accrued Expenses And Other Liabilities', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumeShortTermBorrowings', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assume Short-Term Borrowings', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAccountsPayableAndAccruedExpenses', 'Business Combination Recognized Identifiable Assets Acquired And Liabilities Assumed Accounts Payable And Accrued Expenses', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAcquiredTechnology', 'Business Combination Recognized Identifiable Assets Acquired And Liabilities Assumed Acquired Technology', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAcquiredTradeName', 'Business Combination Recognized Identifiable Assets Acquired And Liabilities Assumed Acquired Trade Name', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssets', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Assets', 2),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedAssetsHeldForSale', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Assets Held For Sale', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedBrokerDealerPayableToCustomer', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Broker-Dealer, Payable To Customer', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedBrokerDealerPayableToOtherBrokerDealerAndClearingOrganization', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Broker-Dealer, Payable To Other Broker-Dealer And Clearing Organization', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCapitalizedSoftware', 'Business Combination Recognized Identifiable Assets Acquired And Liabilities Assumed Capitalized Software', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCashAndEquivalents', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Cash and Equivalents', 2),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCashAndSecuritiesSegregatedUnderFederalAndOtherRegulations', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Cash and Securities Segregated under Federal and Other Regulations', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentAssetsOther', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Current Assets, Other', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentAssetsPrepaidExpenseAndOtherAssets', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Current Assets, Prepaid Expense and Other Assets', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentAssetsReceivables', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Current Assets, Receivables', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCurrentLiabilitiesDeferredRevenue', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Current Liabilities, Deferred Revenue', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedCustomerRelationships', 'Business Combination Recognized Identifiable Assets Acquired And Liabilities Assumed Customer Relationships', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedDeferredTaxLiabilities', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Deferred Tax Liabilities', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedFeesInterestAndOther', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Fees, Interest And Other', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedFinancialInstrumentsOwnedAtFairValue', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Financial Instruments Owned, At Fair Value', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedFinancialInstrumentsSoldNotYetPurchasedAtFairValue', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Financial Instruments Sold, Not Yet Purchased, At Fair Value', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedInvestmentsInAndAdvanceToAffiliatesSubsidiariesAssociatesAndJointVentures', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Investments In And Advance to Affiliates, Subsidiaries, Associates, And Joint Ventures', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLeaseLiabilities', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Lease Liabilities', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLiabilities', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Liabilities', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedLiabilitiesHeldForSale', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Liabilities Held For Sale', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedNet', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Net', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedNoncurrentLiabilitiesLongTermDebt', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Noncurrent Liabilities, Long-Term Debt', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedPropertyPlantAndEquipment', 'Business Combination, Recognized Identifiable Assets Acquired and Liabilities Assumed, Property, Plant, and Equipment', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredAndLiabilitiesAssumedReceivableFromBrokerDealerAndClearingOrganization', 'Business Combination, Recognized Identifiable Assets Acquired And Liabilities Assumed, Receivable From Broker-Dealer And Clearing Organization', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredGoodwillAndLiabilitiesAssumedLessNoncontrollingInterest', 'Business Combination, Recognized Identifiable Assets Acquired, Goodwill, and Liabilities Assumed, Less Noncontrolling Interest', 1),
#  ('BusinessCombinationRecognizedIdentifiableAssetsAcquiredGoodwillAndLiabilitiesAssumedNet', 'Business Combination, Recognized Identifiable Assets Acquired, Goodwill, and Liabilities Assumed, Net', 1),
#  ('BusinessCombinationStepAcquisitionEquityInterestInAcquireeIncludingSubsequentAcquisitionPercentage', 'Business Combination, Step Acquisition, Equity Interest in Acquiree, Including Subsequent Acquisition, Percentage', 1),
#  ('BusinessCombinationStepAcquisitionEquityInterestInAcquireePercentage', 'Business Combination, Step Acquisition, Equity Interest in Acquiree, Percentage', 2),
#  ('BusinessCombinationStepAcquisitionEquityInterestInAcquireeRemeasurementGain', 'Business Combination, Step Acquisition, Equity Interest in Acquiree, Remeasurement Gain', 1),
#  ('BusinessCustomers', 'Business customers', 1),
#  ('BusinessDevelopment', 'Business Development', 2),
#  ('CancellationOfCommonSharesAmount', 'Cancellation of Common Shares, amount', 1),
#  ('CancellationOfCommonSharesShares', 'Cancellation of Common Shares, shares', 1),
#  ('CancellationOfCommonStock', 'Cancelled common stock', 1),
#  ('CancelledCommonStockAmount', 'Cancelled common stock, amount', 1),
#  ('CancelledCommonStockShares', 'Cancelled common stock, shares', 1),
#  ('CancelledSeriesEPreferredStockAmount', 'Cancelled Series E Preferred stock, amount', 1),
#  ('CancelledSeriesEPreferredStockShares', 'Cancelled Series E Preferred stock, shares', 1),
#  ('CapitalDistributionsSpinoffTransaction', 'Capital Distributions, Spinoff Transaction', 1),
#  ('CapitalExpendituresIncurredButNotYetPaid', 'Capital Expenditures Incurred but Not yet Paid', 1),
#  ('CapitalIncrease', 'Capital increase', 1),
#  ('CapitalIncreaseInAfilliate', 'Capital increase in afilliate', 1),
#  ('CapitalRequiredForCapitalAdequacy', 'Banking Regulation, Total Risk-Based Capital, Capital Adequacy, Minimum', 1),
#  ('CapitalRequiredForCapitalAdequacyToRiskWeightedAssets', 'Banking Regulation, Total Risk-Based Capital Ratio, Capital Adequacy, Minimum', 1),
#  ('CapitalStockPerShare', 'Capital stock per share', 1),
#  ('CapitalToRiskWeightedAssets', 'Banking Regulation, Total Risk-Based Capital Ratio, Actual', 1),
#  ('CapitalUnits', 'Capital Units, Value', 1),
#  ('CapitalizedComputerSoftwareAccumulatedAmortization', 'Capitalized Computer Software, Accumulated Amortization', 1),
#  ('CapitalizedComputerSoftwareAccumulatedImpairment', 'Capitalized Computer Software Accumulated Impairment', 1),
#  ('CapitalizedComputerSoftwareGross', 'Capitalized Computer Software, Gross', 2),
#  ('CapitalizedComputerSoftwareImpairments1', 'Capitalized Computer Software, Impairments', 1),
#  ('CapitalizedComputerSoftwareNet', 'Capitalized Computer Software, Net', 1),
#  ('CapitalizedComputerSoftwarePeriodIncreaseDecrease', 'Capitalized Computer Software, Period Increase (Decrease)', 1),
#  ('CapitalizedContractCostAmortization', 'Capitalized Contract Cost, Amortization', 1),
#  ('CapitalizedContractCostNet', 'Capitalized Contract Cost, Net', 1),
#  ('CapitalizedSoftwareDevelopmentCostsForSoftwareSoldToCustomers', 'Capitalized Software Development Costs for Software Sold to Customers', 1),
#  ('CapitalizedSoftwareIncludedInAccruedExpenses', 'Capitalized Software Included In Accrued Expenses', 1),
#  ('CardInterchangeFees', 'Card Interchange Fees', 1),
#  ('CarryingAmountOfEquityInvestments', 'Carrying Amount Of Equity Investments', 1),
#  ('Cash', 'Cash', 5),
#  ('CashAcquiredFromAcquisition', 'Cash Acquired from Acquisition', 1),
#  ('CashAndCashEquivalents', 'Cash and cash equivalents', 1),
#  ('CashAndCashEquivalentsAtCarryingValue', 'Cash and Cash Equivalents, at Carrying Value', 13),
#  ('CashAndCashEquivalentsDomestic', 'Cash And Cash Equivalents, Domestic', 1),
#  ('CashAndCashEquivalentsFairValueDisclosure', 'Cash and Cash Equivalents, Fair Value Disclosure', 5),
#  ('CashAndCashEquivalentsForeign', 'Cash And Cash Equivalents, Foreign', 1),
#  ('CashAndCashEquivalentsIncreaseDecreaseDueToConsolidationAndDeconsolidationOfInvestmentProducts', 'Cash And Cash Equivalents Increase (Decrease) Due To Consolidation And Deconsolidation Of Investment Products', 1),
#  ('CashAndDueFromBanks', 'Cash and Due from Banks', 1),
#  ('CashAndSecuritiesSegregatedUnderFederalAndOtherRegulations', 'Cash and Securities Segregated under Federal and Other Regulations', 2),
#  ('CashAndSecuritiesSegregatedUnderFederalAndOtherRegulationsFairValueDisclosure', 'Cash And Securities Segregated Under Federal And Other Regulations, Fair Value Disclosure', 1),
#  ('CashAndSecuritiesSegregatedUnderSecuritiesExchangeCommissionRegulation', 'Cash and Securities Segregated under Securities Exchange Commission Regulation', 1),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents', 'Cash, Cash Equivalents, Restricted Cash, and Restricted Cash Equivalents', 12),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsContinuingOperations', 'Cash Cash Equivalents Restricted Cash And Restricted Cash Equivalents Continuing Operations', 1),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations', 'Cash, Cash Equivalents, Restricted Cash, and Restricted Cash Equivalents, Including Disposal Group and Discontinued Operations', 4),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect', 'Cash, Cash Equivalents, Restricted Cash, and Restricted Cash Equivalents, Period Increase (Decrease), Excluding Exchange Rate Effect', 6),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect', 'Cash, Cash Equivalents, Restricted Cash, and Restricted Cash Equivalents, Period Increase (Decrease), Including Exchange Rate Effect', 9),
#  ('CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffectDisposalGroupIncludingDiscontinuedOperations', 'Cash, Cash Equivalents, Restricted Cash, and Restricted Cash Equivalents, Period Increase (Decrease), Including Exchange Rate Effect, Disposal Group, Including Discontinued Operations', 1),
#  ('CashCollateralForBorrowedSecurities', 'Cash Collateral for Borrowed Securities', 1),
#  ('CashCollateralPledge', 'Cash Collateral Pledge', 1),
#  ('CashCollateralReceived', 'Cash Collateral Received', 1),
#  ('CashDivestedFromDeconsolidation', 'Cash Divested from Deconsolidation', 1),
#  ('CashEquivalentsAtCarryingValue', 'Cash Equivalents, at Carrying Value', 1),
#  ('CashFDICInsuredAmount', 'Cash, FDIC Insured Amount', 1),
#  ('CashFlowHedgeGainLossToBeReclassifiedWithinTwelveMonths', 'Cash Flow Hedge Gain (Loss) to be Reclassified within 12 Months', 1),
#  ('CashFlowsBetweenTransfereeAndTransferorProceedsFromNewTransfers', 'Cash Flows Between Transferor and Transferee, Proceeds from New Transfers', 1),
#  ('CashFlowsFromUsedInFinancingActivities', 'Cash flows from (used in) financing activities', 1),
#  ('CashFlowsFromUsedInInvestingActivities', 'Cash flows from (used in) investing activities', 1),
#  ('CashFlowsFromUsedInOperations', 'Cash flows from (used in) operations', 1),
#  ('CashFlowsUsedInObtainingControlOfSubsidiariesOrOtherBusinessesClassifiedAsInvestingActivities', 'Cash flows used in obtaining control of subsidiaries or other businesses, classified as investing activities', 1),
#  ('CashInterestPaidByConsolidatedInvestmentProducts', 'Cash Interest Paid By Consolidated Investment Products', 1),
#  ('CashPaid', 'Cash Paid', 1),
#  ('CashProceedsFromSaleOfCryptocurrency', 'Cash proceeds from the sale of cryptocurrency', 1),
#  ('CashReturnedFromBusinessCombinationWorkingCapitalSettlement', 'Cash Returned From Business Combination Working Capital Settlement', 1),
#  ('CashSegregatedUnderOtherRegulations', 'Cash Segregated under Other Regulations', 1),
#  ('CashToBeTransferred', 'Cash to be transferred', 1),
#  ('CashTransferred', 'Cash transferred', 1),
#  ('CashUnderwritingDiscountWereExercised', 'Cash underwriting discount were exercised', 1),
#  ('CashWithdrawnFromTrustAccountInConnectionWithRedemption', 'Cash withdrawn from Trust Account in connection with redemption', 1),
#  ('ChangeInDerivativeLiability', 'Change in derivative liability', 1),
#  ('ChangeInFairValueOfConvertibleDebt', 'Change In Fair Value Of Convertible Debt', 1),
#  ('ChangeInFairValueOfWarrantLiability', 'Change in fair value of warrant liability', 1),
#  ('ChangeInFairValueReportedInOtherComprehensiveIncome', 'Change In Fair Value Reported In Other Comprehensive Income', 1),
#  ('ChangeInUnrealizedAppreciationDepreciationOnDerivativesRecognizedInIncome', 'Change in unrealized appreciation depreciation on derivatives recognized in income', 1),
#  ('ChangeInUnrealizedGainLossOnCashFlowHedgingInstrumentsRelatedToInterestSettlements', 'Change In Unrealized Gain (Loss) On Cash Flow Hedging Instruments, Related To Interest Settlements', 1),
#  ('ChangeInUnrealizedGainLossOnFairValueHedgingInstruments1', 'Change in Unrealized Gain (Loss) on Fair Value Hedging Instruments', 2),
#  ('ChangeInUnrealizedGainLossOnFairValueHedgingInstrumentsRelatedToInterestSettlements', 'Change In Unrealized Gain (Loss) On Fair Value Hedging Instruments, Related To Interest Settlements', 1),
#  ('ChangeInUnrealizedGainLossOnHedgedItemInFairValueHedge1', 'Change in Unrealized Gain (Loss) on Hedged Item in Fair Value Hedge', 2),
#  ('ChangeInValuationAllowance', 'Change in valuation allowance', 1),
#  ('ChangesInFairValueReportedInStatementsOfOperations', 'Changes In Fair Value Reported In Statements Of Operations', 1),
#  ('ClassOfWarrantOrRighstFromWhichWarrantsOrRightsExpired', 'Class Of Warrant Or Righst From Which Warrants Or Rights Expired', 1),
#  ('ClassOfWarrantOrRightExercisePriceOfWarrantsOrRights1', 'Class of Warrant or Right, Exercise Price of Warrants or Rights', 5),
#  ('ClassOfWarrantOrRightNumberOfSecuritiesCalledByEachWarrantOrRight', 'Class of Warrant or Right, Number of Securities Called by Each Warrant or Right', 1),
#  ('ClassOfWarrantOrRightNumberOfSecuritiesCalledByWarrantsOrRights', 'Warrants issued', 2),
#  ('ClassOfWarrantOrRightOutstanding', 'Warrants outstanding', 4),
#  ('CmbsSecuritizationAssets', 'Cmbs Securitization Assets', 1),
#  ('CoSelectedMeasureAmt', 'Company Selected Measure Amount', 4),
#  ('CollateralAlreadyPostedAggregateFairValue', 'Collateral Already Posted, Aggregate Fair Value', 1),
#  ('CollateralReceivedAggregateFairValue', 'Collateral Received, Aggregate Fair Value', 1),
#  ('CollateralizedFinancingTransactionsSecuritiesBorrowingArrangements', 'Collateralized Financing Transactions Securities Borrowing Arrangements', 1),
#  ('CollateralizedFinancingTransactionsSecuritiesBorrowingArrangementsCollateral', 'Collateralized Financing Transactions Securities Borrowing Arrangements Collateral', 1),
#  ('CollateralizedFinancingTransactionsSecuritiesBorrowingArrangementsPledgedSecuritiesCollateral', 'Collateralized Financing Transactions Securities Borrowing Arrangements Pledged Securities Collateral', 1),
#  ('CollateralizedFinancingTransactionsSecuritiesBorrowingArrangementsRepurchaseAgreements', 'Collateralized Financing Transactions Securities Borrowing Arrangements Repurchase Agreements', 1),
#  ('CollateralizedFinancingsMeasurementInput', 'Collateralized Financings, Measurement Input', 1),
#  ('CollateralizedLoanObligationsSecuritizationAssets', 'Collateralized Loan Obligations Securitization Assets', 1),
#  ('CollectionOfLoansFromCustomersHoldingUSStocks', 'Collection Of Loans From Customers Holding USStocks', 1),
#  ('CommercialLoanFundingPayabletoParent', 'Commercial Loan Funding, Payable to Parent', 1),
#  ('CommercialPaper', 'Commercial Paper', 1),
#  ('CommissionExpense', 'Commission expense', 1),
#  ('CommissionExpensePercentage', 'Commission Expense Percentage', 1),
#  ('CommissionExpenses', 'Commission Expenses', 1),
#  ('CommissionsAndBonusReceivable', 'Commissions and Bonus Receivable', 1),
#  ('CommitmentsAndContingencies', 'Commitments and contingencies (Note 14)', 9),
#  ('CommitmentsUnderEquityCapitalizationOfJointVentureEntity', 'Commitments Under Equity Capitalization Of Joint Venture Entity', 1),
#  ('CommitmenttoExtendCreditWeightedAverageInterestRate', 'Commitment to Extend Credit, Weighted Average Interest Rate', 1),
#  ('CommonSharesAndWarrantsIssuedInConnectionWithUnitOfferingNetOfIssueCosts', 'Common Shares And Warrants Issued In Connection With Unit Offering Net Of Issue Costs', 1),
#  ('CommonSharesAndWarrantsIssuedInConnectionWithUnitOfferingNetOfIssueCostsShares', 'Common Shares And Warrants Issued In Connection With Unit Offering Net Of Issue Costs Shares', 1),
#  ('CommonStockAsConvertedOwnershipPercentage', 'Common Stock, As Converted, Ownership Percentage', 1),
#  ('CommonStockCapitalSharesReservedForFutureIssuance', 'Common Stock, Capital Shares Reserved for Future Issuance', 2),
#  ('CommonStockConvertibleConversionPriceIncrease', 'Common Stock, Convertible, Conversion Price, Increase', 1),
#  ('CommonStockDividendsPerShareCashPaid', 'Common Stock, Dividends, Per Share, Cash Paid', 3),
#  ('CommonStockDividendsPerShareDeclared', 'Common Stock, Dividends, Per Share, Declared', 2),
#  ('CommonStockFullyDilutedAsConvertedOwnershipPercentage', 'Common Stock, Fully Diluted, As Converted, Ownership Percentage', 1),
#  ('CommonStockHeldByNonAffiliate', 'Common Stock Held By Non Affiliate', 1),
#  ('CommonStockParOrStatedValuePerShare', 'Common stock, par value', 14),
#  ('CommonStockShareSubscribedButUnissuedSubscriptionsReceivable', 'Common Stock, Share Subscribed but Unissued, Subscriptions Receivable', 1),
#  ('CommonStockSharesAuthorized', 'Common stock, shares authorized', 12),
#  ('CommonStockSharesCancelled', 'Cancelled shares', 1),
#  ('CommonStockSharesIssued', 'Common stock, shares issued', 13),
#  ('CommonStockSharesOutstanding', 'Common stock, shares outstanding', 14),
#  ('CommonStockSharesSubscribedButUnissued', 'Common Stock, Shares Subscribed but Unissued', 1),
#  ('CommonStockSubjectToPossibleRedemption', 'Redemption of Common Stock', 1),
#  ('CommonStockSubjectToPossibleRedemptionPricePerShare', 'Price per share, subject to possible redemption', 1),
#  ('CommonStockValue', 'Common stock, $0.001 par value; 100,000,000 and 50,000,000 shares authorized as of December 31, 2022 and December 31, 2021; 15,193,587 and 13,466,603 ... (31 characters truncated) ... 1, 2022 and December 31, 2021, respectively; 15,166,596 and 13,439,612 shares outstanding as of December 31, 2022 and December 31, 2021, respectively', 13),
#  ('CommonUnitIssued', 'Common Unit, Issued', 1),
#  ('CommonWarrantsShares', 'Common Warrants Shares', 1),
#  ('CommunicationsAndInformationTechnology', 'Communications and Information Technology', 3),
#  ('CompanyOwnedToTheCompanyOfficer', 'Company owned to the company officer', 1),
#  ('CompensationExpenseModificationOfExcessDividend', 'Compensation Expense, Modification of Excess Dividend', 1),
#  ('ComprehensiveIncome', 'Comprehensive income', 1),
#  ('ComprehensiveIncomeAttributableToNoncontrollingInterests', 'Comprehensive income, attributable to non-controlling interests', 1),
#  ('ComprehensiveIncomeAttributableToOwnersOfParent', 'Comprehensive income, attributable to owners of parent', 1),
#  ('ComprehensiveIncomeLossNetOfTaxAttributableToRedeemableNoncontrollingInterests', 'Comprehensive Income (Loss) Net Of Tax, Attributable To Redeemable Noncontrolling Interests', 1),
#  ('ComprehensiveIncomeNetOfTax', 'Comprehensive Income (Loss), Net of Tax, Attributable to Parent', 8),
#  ('ComprehensiveIncomeNetOfTaxAttributableToNoncontrollingInterest', 'Comprehensive Income (Loss), Net of Tax, Attributable to Noncontrolling Interest', 1),
#  ('ComprehensiveIncomeNetOfTaxIncludingPortionAttributableToNoncontrollingInterest', 'Comprehensive Income (Loss), Net of Tax, Including Portion Attributable to Noncontrolling Interest', 4),
#  ('ConcentrationOfRiskPercentageForCustomerConcentrationBasedOnBenchmarkOfAmountReceivable', 'Concentration of Risk Percentage For Customer Concentration Based On Benchmark Of Amount Receivable', 1),
#  ('ConcentrationRiskNumberOfBorrowers', 'Concentration Risk Number of Borrowers', 1),
#  ('ConcentrationRiskPercentage1', 'Concentration Risk, Percentage', 5),
# ...
#  ('FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilityIssues', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability, Issuances', 1),
#  ('FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilityPurchases', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability, Purchases', 1),
#  ('FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilitySales', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability, Sales', 1),
#  ('FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilitySettlements', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability, Settlements', 1),
#  ('FairValueMeasurementWithUnobservableInputsReconciliationRecurringBasisLiabilityTransfersNet', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability, Transfers, Net', 1),
#  ('FairValueMeasurementWithUnobservableInputsReconciliationsRecurringBasisLiabilityValue', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Liability Value', 1),
#  ('FairValueMeasurementwithUnobservableInputsReconciliationRecurringBasisAssetsConsolidationDeconsolidation', 'Fair Value, Measurement with Unobservable Inputs Reconciliation, Recurring Basis, Assets, Consolidation (Deconsolidation)', 1),
#  ('FairValueMeasurementwithUnobservableInputsReconciliationsRecurringBasisAssetExclusionValue', 'Fair Value, Measurement with Unobservable Inputs Reconciliations, Recurring Basis, Asset Exclusion Value', 1),
#  ('FairValueMeasurementwithUnobservableInputsReconciliationsRecurringBasisLiabilityExclusionValue', 'Fair Value, Measurement with Unobservable Inputs Reconciliations, Recurring Basis, Liability Exclusion Value', 1),
#  ('FairValueNetDerivativeAssetLiabilityMeasuredOnRecurringBasisUnobservableInputsReconciliationGainLossIncludedInEarnings', 'Fair Value, Net Derivative Asset (Liability) Measured on Recurring Basis, Unobservable Inputs Reconciliation, Gain (Loss) Included in Earnings', 1),
#  ('FairValueNetDerivativeAssetLiabilityMeasuredOnRecurringBasisWithUnobservableInputs', 'Fair Value, Net Derivative Asset (Liability) Measured on Recurring Basis with Unobservable Inputs', 1),
#  ('FairValueOfOverCounterDerivativesAssetsCounterpartyCreditQualityBbOrLower', 'Fair Value Of Over Counter Derivatives Assets Counterparty Credit Quality Bb or Lower', 1),
#  ('FairValueOfOverCounterDerivativesAssetsCounterpartyCreditQualityBbbToBbb', 'Fair Value Of Over Counter Derivatives Assets Counterparty Credit Quality Bbb To Bbb', 1),
#  ('FairValueOfOverCounterDerivativesAssetsCounterpartyCreditQualityUnrated', 'Fair Value Of Over Counter Derivatives Assets Counterparty Credit Quality Unrated', 1),
#  ('FairValueOfOverCounterDerivativesAssetsCounterpartyCreditQualityaOrHigher', 'Fair Value Of Over Counter Derivatives Assets Counterparty Credit QualityA Or Higher', 1),
#  ('FairValueOfSecuritiesReceivedAsCollateralThatCanBeResoldOrRepledged', 'Fair Value of Securities Received as Collateral that Can be Resold or Repledged', 1),
#  ('FairValueOfTheOptionAtTheGrantshareDate', 'Fair value of the option at the grant/share date', 1),
#  ('FairValueOptionAggregateDifferencesLoansAndLongTermReceivables', 'Fair Value, Option, Aggregate Differences, Loans and Long-Term Receivables', 2),
#  ('FairValueOptionAggregateDifferencesLongtermAndShortTermDebtInstruments', 'Fair Value, Option, Aggregate Differences, Long-term And Short-Term Debt Instruments', 1),
#  ('FairValueOptionAggregateDifferencesOtherSecuredFinancings', 'Fair Value, Option, Aggregate Differences, Other Secured Financings', 1),
#  ('FairValueOptionChangesInFairValueGainLoss1', 'Fair Value, Option, Changes in Fair Value, Gain (Loss)', 2),
#  ('FairValueOptionCreditRiskGainsLossesOnAssets', 'Fair Value, Option, Credit Risk, Gains (Losses) on Assets', 1),
#  ('FairValueOptionLoansHeldAsAssets90DaysOrMorePastDue', 'Fair Value, Option, Loans Held as Assets, 90 Days or More Past Due', 1),
#  ('FairValueOptionLoansHeldAsAssets90DaysOrMorePastDueAggregateDifference', 'Fair Value, Option, Loans Held as Assets, 90 Days or More Past Due, Aggregate Difference', 1),
#  ('FairValueOptionLoansHeldAsAssetsAggregateAmountInNonaccrualStatus', 'Fair Value, Option, Loans Held as Assets, Aggregate Amount in Nonaccrual Status', 1),
#  ('FairValueOptionLoansHeldAsAssetsAggregateAmountInNonaccrualStatusAggregatedDifference', 'Fair Value, Option, Loans Held as Assets, Aggregate Amount in Nonaccrual Status, Aggregated Difference', 1),
#  ('FairValueofSeniorSecuredTermLoanReceivable', 'Fair Value of Senior Secured Term Loan Receivable', 1),
#  ('FdicAndPrimaryFederalRegulatorFees', 'FDIC and Primary Federal Regulator Fees', 1),
#  ('FederalDepositInsuranceCorporationPremiumExpense', 'Federal Deposit Insurance Corporation Premium Expense', 1),
#  ('FederalHomeLoanBankAdvancesGeneralDebtObligationsDisclosuresCollateralPledged1', 'Federal Home Loan Bank, Advances, General Debt Obligations, Disclosures, Collateral Pledged', 2),
#  ('FederalHomeLoanBankAdvancesLongTermAndOtherBorrowingsFairValueDisclosure', 'Federal Home Loan Bank Advances, Long Term and Other Borrowings, Fair Value Disclosure', 1),
#  ('FederalHomeLoanBankBorrowingsFairValueDisclosure', 'Federal Home Loan Bank Borrowings, Fair Value Disclosure', 1),
#  ('FederalHomeLoanBankStock', 'Federal Home Loan Bank Stock', 2),
#  ('FederalIncomeTaxExpenseBenefitContinuingOperations', 'Federal Income Tax Expense (Benefit), Continuing Operations', 1),
#  ('FederalIncomeTaxesValuationAllowance', 'Less: valuation allowance', 1),
#  ('FederalReserveBankAdvancesCollateralPledged', 'Federal Reserve Bank, Advances, Collateral Pledged', 1),
#  ('FeeAndCommissionExpense', 'Fee and commission expense', 1),
#  ('FeeAndCommissionIncome', 'Fee and commission income', 1),
#  ('FeeAndCommissionIncomeExpense', 'Fee and commission income (expense)', 1),
#  ('FeesAndCommissionsMortgageBankingAndServicing', 'Fees and Commissions, Mortgage Banking and Servicing', 2),
#  ('FeesEarnedToJointVentureRelatedToLoanOrigination', 'Fees Earned To Joint Venture Related To Loan Origination', 1),
#  ('FeesInterestAndOther', 'Fees Interest And Other', 1),
#  ('FeesPaidToJointVentureRelatedToLoanOrigination', 'Fees Paid To Joint Venture Related To Loan Origination', 1),
#  ('FinanceFeeForWarrantsIssuedInConnectionWithLicenseAgreement', 'Finance fee for warrants issued in connection with license agreement', 1),
#  ('FinanceLeaseLiability', 'Finance Lease, Liability', 1),
#  ('FinanceLeasePrincipalPayments', 'Finance Lease, Principal Payments', 1),
#  ('FinancialAdvisorSuccessFees', 'Financial Advisor Success Fees', 1),
#  ('FinancialAssets', 'Financial Assets', 1),
#  ('FinancialAssets', 'Financial assets', 1),
#  ('FinancialAssetsAtAmortisedCost', 'Financial assets at amortised cost', 1),
#  ('FinancialAssetsAtFairValue', 'Financial assets, at fair value', 1),
#  ('FinancialAssetsAtNotionalAmount', 'Financial assets, at notional amount', 1),
#  ('FinancialAssetsHeldForManagingLiquidityRisk', 'Financial assets held for managing liquidity risk', 1),
#  ('FinancialAssetsLiabilitiesAtAmortisedCost', 'Financial Assets (Liabilities), At Amortised Cost', 1),
#  ('FinancialAssetsLiabilitiesAtFairValue', 'Financial Assets (Liabilities), At Fair Value', 1),
#  ('FinancialAssetsLiabilitiesAtNotional', 'Financial Assets (Liabilities), At Notional', 1),
#  ('FinancialAssetsSoldUnderAgreementsToRepurchaseGrossIncludingNotSubjectToMasterNettingArrangement', 'Financial Assets Sold under Agreements to Repurchase, Gross Including Not Subject to Master Netting Arrangement', 1),
#  ('FinancialInstrumentsOwnedAtFairValue', 'Financial instruments fair value', 1),
#  ('FinancialInstrumentsOwnedCommonStockWarrantsAtFairValue', 'Financial Instruments, Owned, Common Stock Warrants, At Fair Value', 1),
#  ('FinancialInstrumentsOwnedMeasurementInput', 'Financial Instruments, Owned, Measurement Input', 1),
#  ('FinancialInstrumentsOwnedSubordinatedBondsAtFairValue', 'Financial Instruments, Owned, Subordinated Bonds, At Fair Value', 1),
#  ('FinancialInstrumentsOwnedatFairValueExcludingInvestmentsatNetAssetValue', 'Financial Instruments, Owned, at Fair Value Excluding Investments at Net Asset Value', 1),
#  ('FinancialInstrumentsSoldNotYetPurchasedAtFairValue', 'Financial Instruments Sold, Not yet Purchased, at Fair Value', 1),
#  ('FinancialInstrumentsSoldNotYetPurchasedDerivativesAndOtherContracts', 'Financial Instruments Sold, Not yet Purchased, Derivatives and Other Contracts', 1),
#  ('FinancialInstrumentsSoldNotYetPurchasedMeasurementInput', 'Financial Instruments Sold, Not Yet Purchased, Measurement Input', 1),
#  ('FinancialLiabilities', 'Financial Liabilities', 1),
#  ('FinancialLiabilities', 'Financial liabilities', 1),
#  ('FinancialLiabilitiesAtAmortisedCost', 'Financial liabilities at amortised cost', 1),
#  ('FinancialLiabilitiesAtFairValue', 'Financial liabilities, at fair value', 1),
#  ('FinancialLiabilitiesAtNotionalAmount', 'Financial liabilities, at notional amount', 1),
#  ('FinancialLiabilitiesFairValueDisclosure', 'Financial Liabilities Fair Value Disclosure', 2),
#  ('FinancialLiabilitiesUndiscountedCashFlows', 'Financial Liabilities, Undiscounted Cash Flows', 1),
#  ('FinancingReceivableAccruedInterestAfterAllowanceForCreditLoss', 'Financing Receivable, Accrued Interest, after Allowance for Credit Loss', 1),
#  ('FinancingReceivableAccruedInterestBeforeAllowanceForCreditLoss', 'Financing Receivable, Accrued Interest, before Allowance for Credit Loss', 2),
#  ('FinancingReceivableAllowanceForCreditLossExcludingAccruedInterest', 'Financing Receivable, Allowance for Credit Loss, Excluding Accrued Interest', 4),
#  ('FinancingReceivableAllowanceForCreditLossForeignCurrencyTranslation', 'Financing Receivable, Allowance for Credit Loss, Foreign Currency Translation', 1),
#  ('FinancingReceivableAllowanceForCreditLossModificationOfLoans', 'Financing Receivable, Allowance for Credit Loss, Modification of Loans', 1),
#  ('FinancingReceivableAllowanceForCreditLossPurchasedWithCreditDeteriorationIncrease', 'Financing Receivable, Allowance for Credit Loss, Purchased with Credit Deterioration, Increase', 1),
#  ('FinancingReceivableAllowanceForCreditLossRecoveryIncludingOffBalanceSheetCreditLossLiability', 'Financing Receivable, Allowance for Credit Loss, Recovery, Including Off-Balance Sheet, Credit Loss, Liability', 1),
#  ('FinancingReceivableAllowanceForCreditLossRoundedAmount', 'Financing Receivable, Allowance for Credit Loss, Rounded Amount', 1),
#  ('FinancingReceivableAllowanceForCreditLossToNonaccrualPercent', 'Financing Receivable, Allowance for Credit Loss to Nonaccrual, Percent', 1),
#  ('FinancingReceivableAllowanceForCreditLossToOutstandingPercent', 'Financing Receivable, Allowance for Credit Loss to Outstanding, Percent', 1),
#  ('FinancingReceivableAllowanceForCreditLosses', 'Financing Receivable, Allowance for Credit Loss', 1),
#  ('FinancingReceivableAllowanceForCreditLossesCollectivelyEvaluatedForImpairment', 'Financing Receivable, Allowance for Credit Losses, Collectively Evaluated for Impairment', 1),
#  ('FinancingReceivableAllowanceForCreditLossesExcludingAccruedInterestProvisionAndTransfers', 'Financing Receivable, Allowance for Credit Losses, Excluding Accrued Interest, Provision and Transfers', 1),
#  ('FinancingReceivableAllowanceForCreditLossesIndividuallyEvaluatedForImpairment1', 'Financing Receivable, Allowance for Credit Losses, Individually Evaluated for Impairment', 1),
#  ('FinancingReceivableAllowanceForCreditLossesRecovery', 'Financing Receivable, Allowance for Credit Loss, Recovery', 3),
#  ('FinancingReceivableAllowanceForCreditLossesWriteOffs', 'Financing Receivable, Allowance for Credit Loss, Writeoff', 2),
#  ('FinancingReceivableBeforeAllowanceForCreditLossAndFee', 'Financing Receivable, before Allowance for Credit Loss, Fee and Loan in Process', 2),
#  ('FinancingReceivableBeforeAllowanceForCreditLossLoansToMembers', 'Financing Receivable, Before Allowance For Credit Loss, Loans To Members', 1),
#  ('FinancingReceivableBeforeAllowanceForCreditLossNumberOfDefaultedLoansPurchased', 'Financing Receivable, before Allowance for Credit Loss, Number of Defaulted Loans Purchased', 1),
#  ('FinancingReceivableBeforeAllowanceForCreditLossNumberOfDefaults', 'Financing Receivable, before Allowance for Credit Loss, Number of Defaults', 1),
#  ('FinancingReceivableBeforeAllowanceForCreditLossToTotalPercent', 'Financing Receivable, before Allowance for Credit Loss, to Total, Percent', 2),
#  ('FinancingReceivableChargesToAllowanceLoansInProcessAndDeferredFees', 'Financing Receivable, Charges to Allowance, Loans in Process and Deferred Fees', 1),
#  ('FinancingReceivableCollateralForSecuredBorrowings', 'Financing Receivable, Collateral For Secured Borrowings', 1),
#  ('FinancingReceivableCollectivelyEvaluatedForImpairment', 'Financing Receivable, Collectively Evaluated for Impairment', 1),
#  ('FinancingReceivableCommercialNetofDeferredIncomePercentage', 'Financing Receivable Commercial, Net of Deferred Income, Percentage', 1),
#  ('FinancingReceivableExcludingAccruedInterest90DaysOrMorePastDueStillAccruing', 'Financing Receivable, Excluding Accrued Interest, 90 Days or More Past Due, Still Accruing', 1),
#  ('FinancingReceivableExcludingAccruedInterestAfterAllowanceForCreditLoss', 'Financing Receivable, Excluding Accrued Interest, after Allowance for Credit Loss', 4),
#  ('FinancingReceivableExcludingAccruedInterestAfterAllowanceForCreditLossFairValueDisclosure', 'Financing Receivable, Excluding Accrued Interest, after Allowance for Credit Loss, Fair Value Disclosure', 1),
#  ('FinancingReceivableExcludingAccruedInterestAllowanceForCreditLossPeriodIncreaseDecrease', 'Financing Receivable, Excluding Accrued Interest, Allowance for Credit Loss, Period Increase (Decrease)', 1),
#  ('FinancingReceivableExcludingAccruedInterestAllowanceForCreditLossRecovery', 'Financing Receivable, Excluding Accrued Interest, Allowance for Credit Loss, Recovery', 1),
#  ('FinancingReceivableExcludingAccruedInterestAllowanceForCreditLossRecoveryRate', 'Financing Receivable, Excluding Accrued Interest, Allowance for Credit Loss, Recovery Rate', 1),
#  ('FinancingReceivableExcludingAccruedInterestAllowanceForCreditLossWriteoff', 'Financing Receivable, Excluding Accrued Interest, Allowance for Credit Loss, Writeoff', 4),
#  ('FinancingReceivableExcludingAccruedInterestAllowanceForCreditLossWriteoffRate', 'Financing Receivable, Excluding Accrued Interest, Allowance for Credit Loss, Writeoff Rate', 1),
#  ('FinancingReceivableExcludingAccruedInterestBeforeAllowanceForCreditLoss', 'Financing Receivable, Excluding Accrued Interest, before Allowance for Credit Loss', 3),
#  ('FinancingReceivableExcludingAccruedInterestBeforeAllowanceForCreditLossCurrent', 'Financing Receivable, Excluding Accrued Interest, before Allowance for Credit Loss, Current', 1),
#  ('FinancingReceivableExcludingAccruedInterestBeforeAllowanceForCreditLossFeeAndLoanInProcess', 'Financing Receivable, Excluding Accrued Interest, before Allowance for Credit Loss, Fee, and Loan in Process', 2),
#  ('FinancingReceivableExcludingAccruedInterestCreditLossExpenseReversal', 'Financing Receivable, Excluding Accrued Interest, Credit Loss Expense (Reversal)', 4),
#  ('FinancingReceivableExcludingAccruedInterestModifiedAccumulated', 'Financing Receivable, Excluding Accrued Interest, Modified, Accumulated', 2),
#  ('FinancingReceivableExcludingAccruedInterestModifiedPeriod', 'Financing Receivable, Excluding Accrued Interest, Modified in Period, Amount', 1),
#  ('FinancingReceivableExcludingAccruedInterestNonaccrual', 'Financing Receivable, Excluding Accrued Interest, Nonaccrual', 2),
#  ('FinancingReceivableExcludingAccruedInterestNonaccrualNoAllowance', 'Financing Receivable, Excluding Accrued Interest, Nonaccrual, No Allowance', 1),
#  ...]

# %% [markdown]
# **Question 3: Finance company tags and counts of use**

# %% [markdown]
# Note that we used the same SIC list provided by the SEC (https://www.sec.gov/search-filings/standard-industrial-classification-sic-code-list) and assumed that each company used the same name on all submissions.

# %%
# %%sql
# SELECT sum(SUB.pubfloatUSD) assets, SUB.name company_name, SUB.sic sector, count(DISTINCT NUM.tag) num_tags
# FROM SUB NATURAL JOIN NUM
# WHERE SUB.pubfloatUSD is not NULL
# GROUP BY SUB.name, SUB.sic
# ORDER BY assets DESC
# LIMIT 5;
# Out:
#  * postgresql://student@localhost/financial_db
# 5 rows affected.
# [(Decimal('1883648000000000.00'), 'ALPHABET INC.', Decimal('7370'), 334),
#  (Decimal('1054879200000000.00'), 'TESLA, INC.', Decimal('3711'), 434),
#  (Decimal('485800000000000.00'), 'INTEL CORP', Decimal('3674'), 407),
#  (Decimal('285661200000000.00'), 'BOEING CO', Decimal('3721'), 540),
#  (Decimal('231368500000000.00'), 'ADVANCED MICRO DEVICES INC', Decimal('3674'), 332)]

# %% [markdown]
# **Question 4: Display top 5 companies by assets**

# %% [markdown]
# Note that Prof Obaidi specifically linked SIC with sector in direct email and there is no table with the industry text available for display.
